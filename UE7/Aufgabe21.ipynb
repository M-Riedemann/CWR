# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
f = np.loadtxt("A21_GS.csv", delimiter = ",")
plt.imshow(f)

f2 = np.loadtxt("A21_GS2.csv", delimiter = ",")
#plt.contour(f2, 14, colors = "black")
#plt.contourf(f2, 14)
plt.imshow(f2)

X, Y = np.meshgrid(*[np.arange(0, x) for x in f2.shape])

dy, dx = np.gradient(f2)

plt.streamplot(X,Y,dx,dy,color="black")
